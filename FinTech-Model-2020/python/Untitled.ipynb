# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame?

# %%
df3 = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])

# %%
df3
# Out:
#           a         b         c         d         e
# 0  0.156338  0.349041  0.690179 -0.893871 -0.999384
# 1  1.383931  0.210778 -0.391172 -0.909681 -1.455458
# 2 -0.365062  1.971776 -0.572469 -1.523583  0.421758
# 3  1.882974 -1.126251  0.146372  0.426354  0.092291
# 4 -0.614735  0.864459 -1.838610  0.120319 -1.635458
# 5  1.457307  0.151806  0.861289  0.500953  0.363898
# 6 -1.423759  1.459635 -1.841329  1.322311  0.195296
# 7 -2.755558 -0.163702 -1.228097 -1.849219  1.312049
# 8  0.149000 -0.280628  0.768859  0.980686  0.749410
# 9 -0.115418  0.157389  0.640541  0.885695 -0.024153

# %%
importance = [('grade', 37), ('intrate', 254), ('mthssincelastdelinq', 237), ('delinq2yrs', 34), ('annualinc', 350), ('inqlast6mths', 64), ('mthssincerecentbc', 258), ('emptitle_freq', 315), ('loanamnt', 204), ('accopenpast24mths', 203), ('numtloppast12m', 77), ('numactvrevtl', 57), ('totcollamt', 88), ('mosinoldrevtlop', 392), ('ficorangelow', 47), ('totalrevhilim', 213), ('totalacc', 130), ('mortacc', 93), ('numoprevtl', 83), ('mosinoldilacct', 380), ('emplength', 164), ('homeownership_OWN', 9), ('bcutil', 291), ('numiltl', 109), ('tothicredlim', 250), ('numrevtlbalgt0', 86), ('dti', 488), ('mthssincerecentbcdlq', 177), ('numbctl', 96), ('mthssincelastrecord', 159), ('mosinrcntrevtlop', 143), ('installment', 390), ('revolutil', 304), ('zipcode_freq', 284), ('revolbal', 267), ('totalbalexmort', 228), ('bcopentobuy', 301), ('totalbclimit', 259), ('openacc', 76), ('avgcurbal', 297), ('mosinrcnttl', 140), ('totalilhighcreditlimit', 214), ('taxliens', 5), ('numrevaccts', 134), ('subgrade', 128), ('mthssincelastmajorderog', 152), ('zipcode', 280), ('earliestcrline_m', 297), ('mthssincerecentrevoldelinq', 146), ('numsats', 56), ('homeownership_MORTGAGE', 19), ('collections12mthsexmed', 4), ('purpose_small_business', 21), ('totcurbal', 201), ('addrstate_freq', 189), ('mthssincerecentinq', 247), ('homeownership_RENT', 52), ('pcttlnvrdlq', 162), ('numtl120dpd2m', 6), ('ficorangehigh', 129), ('numbcsats', 65), ('verificationstatus_Not Verified', 14), ('purpose_credit_card', 14), ('percentbcgt75', 148), ('verificationstatus_Verified', 15), ('numactvbctl', 58), ('purpose_other', 7), ('withdesc', 11), ('purpose_medical', 14), ('verificationstatus_Source Verified', 31), ('pubrecbankruptcies', 17), ('numacctsever120pd', 34), ('pubrec', 13), ('purpose_debt_consolidation', 20), ('initialliststatus_f', 25), ('purpose_moving', 8), ('numtl90gdpd24m', 5), ('initialliststatus_w', 9), ('purpose_major_purchase', 6), ('purpose_home_improvement', 8), ('delinqamnt', 1), ('chargeoffwithin12mths', 1), ('purpose_house', 1)]

# %%
importance
# Out:
# [('grade', 37),
#  ('intrate', 254),
#  ('mthssincelastdelinq', 237),
#  ('delinq2yrs', 34),
#  ('annualinc', 350),
#  ('inqlast6mths', 64),
#  ('mthssincerecentbc', 258),
#  ('emptitle_freq', 315),
#  ('loanamnt', 204),
#  ('accopenpast24mths', 203),
#  ('numtloppast12m', 77),
#  ('numactvrevtl', 57),
#  ('totcollamt', 88),
#  ('mosinoldrevtlop', 392),
#  ('ficorangelow', 47),
#  ('totalrevhilim', 213),
#  ('totalacc', 130),
#  ('mortacc', 93),
#  ('numoprevtl', 83),
#  ('mosinoldilacct', 380),
#  ('emplength', 164),
#  ('homeownership_OWN', 9),
#  ('bcutil', 291),
#  ('numiltl', 109),
#  ('tothicredlim', 250),
#  ('numrevtlbalgt0', 86),
#  ('dti', 488),
#  ('mthssincerecentbcdlq', 177),
#  ('numbctl', 96),
#  ('mthssincelastrecord', 159),
#  ('mosinrcntrevtlop', 143),
#  ('installment', 390),
#  ('revolutil', 304),
#  ('zipcode_freq', 284),
#  ('revolbal', 267),
#  ('totalbalexmort', 228),
#  ('bcopentobuy', 301),
#  ('totalbclimit', 259),
#  ('openacc', 76),
# ...

# %%
df_importance = pd.DataFrame(importance, columns = ['feature', 'fscore'])

# %%
df_importance
# Out:
#                                feature  fscore
# 0                                grade      37
# 1                              intrate     254
# 2                  mthssincelastdelinq     237
# 3                           delinq2yrs      34
# 4                            annualinc     350
# 5                         inqlast6mths      64
# 6                    mthssincerecentbc     258
# 7                        emptitle_freq     315
# 8                             loanamnt     204
# 9                    accopenpast24mths     203
# 10                      numtloppast12m      77
# 11                        numactvrevtl      57
# 12                          totcollamt      88
# 13                     mosinoldrevtlop     392
# 14                        ficorangelow      47
# 15                       totalrevhilim     213
# 16                            totalacc     130
# 17                             mortacc      93
# 18                          numoprevtl      83
# ...
